# %% [markdown]
# ## Data Cleaning sample and Working with Local Database connection

# %%
# Import modules
import sys
import os
import pandas as pd

# %%
# Append the project root path to sys.path
sys.path.append(os.path.abspath(".."))

# %%
# Now import the modules
from scripts.data_cleaning import load_csv, clean_dataframe, save_cleaned_data
from scripts.database_setup import get_db_connection, create_table, insert_data

# %% [markdown]
# ### Load and Inspect Raw Data

# %%
df = pd.read_csv("../data/processed/cleaned_channels_data.csv")
df.head(10)
# Out:
#       channel_title channel_username  message_id  \
# 0  Doctors Ethiopia       @DoctorsET         864
# 1  Doctors Ethiopia       @DoctorsET         863
# 2  Doctors Ethiopia       @DoctorsET         862
# 3  Doctors Ethiopia       @DoctorsET         861
# 4  Doctors Ethiopia       @DoctorsET         860
# 5  Doctors Ethiopia       @DoctorsET         859
# 6  Doctors Ethiopia       @DoctorsET         848
# 7  Doctors Ethiopia       @DoctorsET         847
# 8  Doctors Ethiopia       @DoctorsET         846
# 9  Doctors Ethiopia       @DoctorsET         845
#
#                                              message  \
# 0  በቀን አንዴ ብቻ የሚባለው የቢዝነስ አማካሪ  በ 10,000 ብር ብቻ የተ...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር  ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ? ሙሉ ቪ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
# 5  ዶክተርስ ኢትዮጽያ በአዲስ ፕሮገራም ጀመረ ማረጥ  (ሜኖፖዝ ) ጋር ተያይ...
# 6  ክረምቱን ስፖርት መስራት አስበው ጂም ለመግባት ካልቻሉ ባሉበት ቦታ ሆነው...
# 7  ስፖርት የመስራት ሱስ ይኖር ይሆን? በአሁኑ ወቅት ብዙ የስፖርት መስሪያ ...
# 8  ድንገተኛ አደጋ / የአጥንት ስብራት አያርገውና ድንገተኛ የሆነ አደጋ ቢደ...
# 9  ከትንሽ ግዚያት በፊት ስፖርት መስራት እንደ ቅንጦት ይታይ ነበር አሁን ላ...
#
#                 message_date                 media_path emoji_used  \
# 0  2023-12-18 17:04:02+00:00  photos\@DoctorsET_864.jpg       👈👈👇👇
# 1  2023-11-03 16:14:39+00:00  photos\@DoctorsET_863.jpg          👇
# 2  2023-10-02 16:37:39+00:00  photos\@DoctorsET_862.jpg   No emoji
# 3  2023-09-16 07:54:32+00:00  photos\@DoctorsET_861.jpg       👇👇👇👇
# 4  2023-09-01 16:16:15+00:00  photos\@DoctorsET_860.jpg   No emoji
# 5  2023-08-29 17:20:05+00:00  photos\@DoctorsET_859.jpg     👇👇👇👇👇👇
# 6  2022-08-02 17:42:08+00:00  photos\@DoctorsET_848.jpg      👇👇👇👇👇
# 7  2022-06-12 17:15:47+00:00  photos\@DoctorsET_847.jpg     👇👇👇👇👇👇
# 8  2022-05-31 17:51:13+00:00  photos\@DoctorsET_846.jpg    👇👇👇👇👇👇👇
# 9  2022-05-20 18:04:53+00:00  photos\@DoctorsET_845.jpg     👇👇👇👇👇👇
#
#                                        youtube_links
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1   https://youtu.be/gwVN5eJQpko?si=xARsSxIEdZtE91GY
# 2   https://youtu.be/oHiSRrNF7I0?si=Absgm414YSt_kjNq
# 3   https://youtu.be/tTeErZxIh_Q?si=jKHyfWcC3sfXbC8L
# 4   https://youtu.be/0k65P5ouw7s?si=qaUgo75bUa3AMQxD
# 5  https://youtu.be/-AR1KO2DbFw?si=47cXLZtlmhx1Nl...
# 6                       https://youtu.be/0uiTzjEbh90
# 7                       https://youtu.be/WPlRuRtQXN8
# 8                       https://youtu.be/QI-8oqW80uI
# 9                       https://youtu.be/_IEWt07bECg

# %%
print(df.columns)
# Out:
# Index(['channel_title', 'channel_username', 'message_id', 'message',
#        'message_date', 'media_path', 'emoji_used', 'youtube_links'],
#       dtype='object')

# %% [markdown]
# ### Clean and Standardize Data

# %%
# Check for missing values in the cleaned DataFrame
missing_values = df.isnull().sum()
missing_values[missing_values > 0]  # Display only columns with missing values
# Out:
# Series([], dtype: int64)

# %%
# Drop the row with missing message_date
cleaned_df = df.dropna(subset=['message_date'])

# %%
# Check for missing values in the cleaned DataFrame
missing_values = cleaned_df.isnull().sum()
missing_values[missing_values > 0]  # Display only columns with missing values
# Out:
# Series([], dtype: int64)

# %%
# Save cleaned data to CSV
save_cleaned_data(df, "../data/processed/cleaned_telegram_data.csv")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 640, in run_forever
#     self._run_once()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 1992, in _run_once
#     handle._run()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hp\AppData\Local\Temp\ipykernel_13172\2088253359.py", line 2, in <module>
#     save_cleaned_data(df, "../data/processed/cleaned_telegram_data.csv")
#   File "c:\Users\Hp\ethiopian_medical_dw\scripts\data_cleaning.py", line 118, in save_cleaned_data
#     raise
# Message: "✅ Cleaned data saved successfully to '../data/processed/cleaned_telegram_data.csv'."
# Arguments: ()
# 2025-01-31 16:36:28,747 - INFO - ✅ Cleaned data saved successfully to '../data/processed/cleaned_telegram_data.csv'.
# ✅ Cleaned data saved successfully to '../data/processed/cleaned_telegram_data.csv'.

# %%
def get_db_connection():
    from sqlalchemy import create_engine
    DATABASE_URL = "postgresql://postgres:1111@localhost:5432/telegram_raw_data"
    engine = create_engine(DATABASE_URL)
    return engine

# %% [markdown]
# ## Connect to Database

# %%
engine = get_db_connection()

# %% [markdown]
# ###  Create Table in PostgreSQL

# %%
create_table(engine)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 640, in run_forever
#     self._run_once()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 1992, in _run_once
#     handle._run()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hp\AppData\Local\Temp\ipykernel_13172\1240587569.py", line 1, in <module>
#     create_table(engine)
#   File "c:\Users\Hp\ethiopian_medical_dw\scripts\database_setup.py", line 61, in create_table
#     logging.info("✅ Table 'telegram_messages' created successfully.")
# Message: "✅ Table 'telegram_messages' created successfully."
# Arguments: ()
# 2025-01-31 16:41:50,044 - INFO - ✅ Table 'telegram_messages' created successfully.

# %% [markdown]
# ###  Insert Data into Database

# %%
# Load the cleaned CSV into a DataFrame
cleaned_df = pd.read_csv("../data/processed/cleaned_telegram_data.csv")

# %%
# Ensure the 'message_date' column is in datetime format (to prevent NaT issues)
cleaned_df["message_date"] = pd.to_datetime(cleaned_df["message_date"], errors="coerce")

# Check if there are any missing values before inserting
missing_values = cleaned_df.isnull().sum()
print("Missing Values Before Insert:", missing_values)
# Out:
# Missing Values Before Insert: channel_title       0
# channel_username    0
# message_id          0
# message             0
# message_date        0
# media_path          0
# emoji_used          0
# youtube_links       0
# dtype: int64

# %%
df
# Out:
#                                          channel_title channel_username  \
# 0                                     Doctors Ethiopia       @DoctorsET
# 1                                     Doctors Ethiopia       @DoctorsET
# 2                                     Doctors Ethiopia       @DoctorsET
# 3                                     Doctors Ethiopia       @DoctorsET
# 4                                     Doctors Ethiopia       @DoctorsET
# ..                                                 ...              ...
# 103  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 104  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 105  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 106  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 107  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
#
#      message_id                                            message  \
# 0           864  በቀን አንዴ ብቻ የሚባለው የቢዝነስ አማካሪ  በ 10,000 ብር ብቻ የተ...
# 1           863  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2           862  ሞት በስኳር  ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ...
# 3           861  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ? ሙሉ ቪ...
# 4           860  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
# ..          ...                                                ...
# 103        2590  #CPD_አሁን_ይመዝገቡ #የሞያ_ፈቃድ_ለማሳደስ_CPD_ይመዝገቡ #Title...
# 104        2589  #Adult_ECHO_Training@#ADISS_ABABA_By_Cardiolog...
# 105        2588                                         No Message
# 106        2587  #OBGYN_አልትራሳውንድ_ስልጠና_አዲስ_አበባ_በስፔሻሊስቶች_ብቻ_የሚሰጥ ...
# 107        2586                                         No Message
#
#                   message_date                 media_path  emoji_used  \
# 0    2023-12-18 17:04:02+00:00  photos\@DoctorsET_864.jpg        👈👈👇👇
# 1    2023-11-03 16:14:39+00:00  photos\@DoctorsET_863.jpg           👇
# 2    2023-10-02 16:37:39+00:00  photos\@DoctorsET_862.jpg    No emoji
# 3    2023-09-16 07:54:32+00:00  photos\@DoctorsET_861.jpg        👇👇👇👇
# 4    2023-09-01 16:16:15+00:00  photos\@DoctorsET_860.jpg    No emoji
# ..                         ...                        ...         ...
# 103  2025-01-22 05:45:11+00:00     photos\@EAHCI_2590.jpg  💥🔶👉📱📱📱📱📳🏃❗
# 104  2025-01-21 08:20:09+00:00     photos\@EAHCI_2589.jpg        👉👉📞📞
# 105  2025-01-20 16:48:10+00:00                   No Media    No emoji
# 106  2025-01-20 06:39:24+00:00     photos\@EAHCI_2587.jpg    ✔💥☎☎☎☎☎🏃
# 107  2025-01-20 06:38:55+00:00                   No Media    No emoji
#
#                                          youtube_links
# 0    https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1     https://youtu.be/gwVN5eJQpko?si=xARsSxIEdZtE91GY
# 2     https://youtu.be/oHiSRrNF7I0?si=Absgm414YSt_kjNq
# 3     https://youtu.be/tTeErZxIh_Q?si=jKHyfWcC3sfXbC8L
# 4     https://youtu.be/0k65P5ouw7s?si=qaUgo75bUa3AMQxD
# ..                                                 ...
# 103                                    No YouTube link
# 104                                    No YouTube link
# 105                                    No YouTube link
# 106                                    No YouTube link
# 107                                    No YouTube link
#
# [108 rows x 8 columns]

# %%
# Insert into the database
insert_data(engine, cleaned_df)
# Out:
# 2025-01-31 16:44:38,669 - INFO - Inserting: 864 - 2023-12-18 17:04:02+00:00
# 2025-01-31 16:44:38,700 - INFO - Inserting: 863 - 2023-11-03 16:14:39+00:00
# 2025-01-31 16:44:38,700 - INFO - Inserting: 862 - 2023-10-02 16:37:39+00:00
# 2025-01-31 16:44:38,700 - INFO - Inserting: 861 - 2023-09-16 07:54:32+00:00
# 2025-01-31 16:44:38,713 - INFO - Inserting: 860 - 2023-09-01 16:16:15+00:00
# 2025-01-31 16:44:38,715 - INFO - Inserting: 859 - 2023-08-29 17:20:05+00:00
# 2025-01-31 16:44:38,719 - INFO - Inserting: 848 - 2022-08-02 17:42:08+00:00
# 2025-01-31 16:44:38,720 - INFO - Inserting: 847 - 2022-06-12 17:15:47+00:00
# 2025-01-31 16:44:38,725 - INFO - Inserting: 846 - 2022-05-31 17:51:13+00:00
# 2025-01-31 16:44:38,728 - INFO - Inserting: 845 - 2022-05-20 18:04:53+00:00
00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2601 - 2025-01-30 09:57:21+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2600 - 2025-01-29 17:00:02+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2598 - 2025-01-29 12:34:11+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2597 - 2025-01-27 11:01:51+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2596 - 2025-01-26 13:17:46+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2595 - 2025-01-26 13:17:40+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2594 - 2025-01-25 08:37:18+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2593 - 2025-01-24 14:09:14+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2592 - 2025-01-24 08:49:19+00:00
# 2025-01-31 16:44:38,936 - INFO - Inserting: 2591 - 2025-01-23 07:31:53+00:00
# 2025-01-31 16:44:38,947 - INFO - Inserting: 2590 - 2025-01-22 05:45:11+00:00
# 2025-01-31 16:44:38,949 - INFO - Inserting: 2589 - 2025-01-21 08:20:09+00:00
# 2025-01-31 16:44:38,950 - INFO - Inserting: 2588 - 2025-01-20 16:48:10+00:00
# 2025-01-31 16:44:38,952 - INFO - Inserting: 2587 - 2025-01-20 06:39:24+00:00
# 2025-01-31 16:44:38,953 - INFO - Inserting: 2586 - 2025-01-20 06:38:55+00:00
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 640, in run_forever
#     self._run_once()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\base_events.py", line 1992, in _run_once
#     handle._run()
#   File "C:\Users\Hp\AppData\Local\Programs\Python\Python312\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\Hp\ethiopian_medical_dw\venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Hp\AppData\Local\Temp\ipykernel_13172\1887784349.py", line 2, in <module>
#     insert_data(engine, cleaned_df)
#   File "c:\Users\Hp\ethiopian_medical_dw\scripts\database_setup.py", line 99, in insert_data
#     logging.info(f"✅ {len(cleaned_df)} records inserted into PostgreSQL database.")
# Message: '✅ 108 records inserted into PostgreSQL database.'
# Arguments: ()
# 2025-01-31 16:44:38,956 - INFO - ✅ 108 records inserted into PostgreSQL database.

# %% [markdown]
# ###  Verify Inserted Data

# %%
query = "SELECT * FROM telegram_messages LIMIT 5;"
df_pg = pd.read_sql(query, engine)

df_pg
# Out:
#    id     channel_title channel_username  message_id  \
# 0   1  Doctors Ethiopia       @DoctorsET         864
# 1   2  Doctors Ethiopia       @DoctorsET         863
# 2   3  Doctors Ethiopia       @DoctorsET         862
# 3   4  Doctors Ethiopia       @DoctorsET         861
# 4   5  Doctors Ethiopia       @DoctorsET         860
#
#                                              message        message_date  \
# 0  በቀን አንዴ ብቻ የሚባለው የቢዝነስ አማካሪ  በ 10,000 ብር ብቻ የተ... 2023-12-18 17:04:02
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ... 2023-11-03 16:14:39
# 2  ሞት በስኳር  ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ... 2023-10-02 16:37:39
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ? ሙሉ ቪ... 2023-09-16 07:54:32
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos... 2023-09-01 16:16:15
#
#                   media_path emoji_used  \
# 0  photos\@DoctorsET_864.jpg       👈👈👇👇
# 1  photos\@DoctorsET_863.jpg          👇
# 2  photos\@DoctorsET_862.jpg   No emoji
# 3  photos\@DoctorsET_861.jpg       👇👇👇👇
# 4  photos\@DoctorsET_860.jpg   No emoji
#
#                                        youtube_links
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1   https://youtu.be/gwVN5eJQpko?si=xARsSxIEdZtE91GY
# 2   https://youtu.be/oHiSRrNF7I0?si=Absgm414YSt_kjNq
# 3   https://youtu.be/tTeErZxIh_Q?si=jKHyfWcC3sfXbC8L
# 4   https://youtu.be/0k65P5ouw7s?si=qaUgo75bUa3AMQxD
